# %% [markdown]
# <a href="https://colab.research.google.com/github/eaadeniyi/acolite/blob/main/acolite_gee_atmCorrection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# `Upload ACOLITE to Google Drive (One-time, 10 minutes)
# *Clone directly to Drive (RECOMMENDED)*`

# %%
# Run this in a Colab cell
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/acolite/acolite.git /content/drive/MyDrive/ACOLITE
print("✓ ACOLITE installed to Google Drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# fatal: destination path '/content/drive/MyDrive/ACOLITE' already exists and is not an empty directory.
# ✓ ACOLITE installed to Google Drive

# %% [markdown]
# Authenticate Google Earth Engine

# %%
import ee

# This will open a browser window for authentication
ee.Authenticate()

# After authentication, initialize
ee.Initialize(project='eaadeniyi')
print("✓ Earth Engine ready")
# Out:
# ✓ Earth Engine ready

# %%
# Initialize with your project
ee.Initialize(project='eaadeniyi')
print("✓ Success!")
# Out:
# ✓ Success!

# %%
test_id = ee.ImageCollection('COPERNICUS/S2_HARMONIZED').first().id().getInfo()
print("✓ EE connection ok; example asset:", test_id)
# Out:
# ✓ EE connection ok; example asset: 20150627T102531_20160606T223605_T31RCL

# %% [markdown]
# `Install dependencies`

# %%
# !pip install netCDF4
# Out:
# Collecting netCDF4
#   Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.9 kB)
# Collecting cftime (from netCDF4)
#   Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2025.10.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from netCDF4) (2.0.2)
# Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 75.5 MB/s eta 0:00:00
# Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.1 MB/s eta 0:00:00
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.6.5 netCDF4-1.7.3

# %%
# !pip -q install --upgrade earthengine-api
# !earthengine set_project eaadeniyi
import ee
ee.Authenticate()
ee.Initialize(project='eaadeniyi')


import sys, os
acolite_path = '/content/drive/MyDrive/ACOLITE'  # repo root that contains the folder "acolite/"
assert os.path.isdir(acolite_path), f"Not found: {acolite_path}"
assert os.path.isdir(os.path.join(acolite_path, 'acolite')), "Folder 'acolite/' missing inside the repo"

if acolite_path not in sys.path:
    sys.path.insert(0, acolite_path)   # add repo root so 'import acolite' works

import acolite
from acolite import gee as acolite_gee
print("✓ Imported ACOLITE from", acolite_path)



print("=== DIAGNOSTIC ===")
print(f"EE module location: {ee.__file__}")

try:
    ee.Initialize(project='eaadeniyi')
    print("✓ Direct initialization works")

    # Try a simple query
    img = ee.Image('COPERNICUS/S2_HARMONIZED/20150627T102531_20160606T223605_T31RCL')
    props = img.getInfo()
    print(f"✓ Can access images: {props['type']}")

    # Try finding scenes
    from acolite import gee as acolite_gee
    images, imColl = acolite_gee.find_scenes(
        '2024-06-15',
        isodate_end='2024-06-15',
        sensors=['S2A_MSI', 'S2B_MSI'],
        limit=[29.67461471404195, -90.17624766298297, 29.971278012572437, -89.78348643251422],
        surface_reflectance=False
    )
    print(f"✓ Can search scenes: found {len(images)} images")

    print("\n✓ ALL TESTS PASSED - main() should work now!")

except Exception as e:
    print(f"\n✗ Error at diagnostic: {e}")
    import traceback
    traceback.print_exc()

# %%
"""
PRODUCTION-READY ACOLITE-GEE PROCESSING SYSTEM
Mississippi River Turbidity Monitoring (2017-2025)
155 Target Dates - Optimized for Google Colab

Author: Custom Configuration for BelleChasse Region
Date: 2025
"""

import ee
import sys
import os
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import json
import time

# !pip -q install --upgrade earthengine-api
# !earthengine set_project eaadeniyi
#import ee
ee.Authenticate()
ee.Initialize(project='eaadeniyi')


acolite_path = '/content/drive/MyDrive/ACOLITE'  # repo root that contains the folder "acolite/"
assert os.path.isdir(acolite_path), f"Not found: {acolite_path}"
assert os.path.isdir(os.path.join(acolite_path, 'acolite')), "Folder 'acolite/' missing inside the repo"

if acolite_path not in sys.path:
    sys.path.insert(0, acolite_path)   # add repo root so 'import acolite' works

import acolite
from acolite import gee as acolite_gee
print("✓ Imported ACOLITE from", acolite_path)


# ============================================================================
# CONFIGURATION SECTION - CUSTOMIZE HERE
# ============================================================================

# Your complete list of 155 target dates
TARGET_DATES = [
    '2022-03-31'
  #'2018-05-08'


]

# Sort dates chronologically
TARGET_DATES = sorted(TARGET_DATES)

# Region configuration
REGION_CONFIG = {
    'limit': [29.67461471404195, -90.17624766298297,
              29.971278012572437, -89.78348643251422],
    'region_name': 'BelleChasse-Region',
    'center_lat': 29.822946,
    'center_lon': -89.979865,
}

# Processing configuration
PROCESSING_CONFIG = {
    'sensors': ['S2A_MSI', 'S2B_MSI'],
    'batch_size': 20,  # Process 20 scenes before checkpoint
}

# Output configuration
OUTPUT_CONFIG = {
    'base_dir': '/content/drive/MyDrive/ACOLITE_Output_Production',
    'organize_by_year': True,  # Create subdirectories by year
}

# ============================================================================
# GOOGLE COLAB SETUP
# ============================================================================

def setup_environment():
    """
    Complete environment setup for Google Colab
    """
    print("="*80)
    print("ACOLITE-GEE PRODUCTION SYSTEM - ENVIRONMENT SETUP")
    print("="*80)

    # Mount Google Drive
    try:
        from google.colab import drive
        drive.mount('/content/drive')
        print("✓ Google Drive mounted")
    except:
        print("⚠ Drive already mounted or not in Colab")

    # Setup ACOLITE
    acolite_path = '/content/drive/MyDrive/ACOLITE'

    if not os.path.exists(acolite_path):
        print("\n⚠ ACOLITE not found on Drive. Cloning...")
        os.system(f'git clone https://github.com/acolite/acolite.git {acolite_path}')
        print("✓ ACOLITE cloned to Drive")

    if acolite_path not in sys.path:
        sys.path.insert(0, acolite_path)

    # Import ACOLITE
    import acolite as ac
    from acolite import gee
    print(f"✓ ACOLITE loaded from: {acolite_path}")

    # Initialize GEE - FIXED VERSION
    print("\nInitializing Google Earth Engine...")

    # Just initialize directly - authentication should already be done
    ee.Initialize(project='eaadeniyi')
    print("✓ Earth Engine initialized with project 'eaadeniyi'")

    # Create output directories
    os.makedirs(OUTPUT_CONFIG['base_dir'], exist_ok=True)
    if OUTPUT_CONFIG['organize_by_year']:
        years = set([d[:4] for d in TARGET_DATES])
        for year in years:
            year_dir = f"{OUTPUT_CONFIG['base_dir']}/{year}"
            os.makedirs(year_dir, exist_ok=True)
        print(f"✓ Created output directories for years: {sorted(years)}")

    print("="*80)
    print("✓ ENVIRONMENT SETUP COMPLETE\n")

    return ac, gee

# ============================================================================
# DATE ANALYSIS AND VALIDATION
# ============================================================================

def analyze_target_dates(target_dates):
    """
    Analyze target dates and provide statistics
    """
    dates = pd.to_datetime(target_dates)

    print("="*80)
    print("TARGET DATES ANALYSIS")
    print("="*80)
    print(f"These are EXACT Sentinel-2 acquisition dates (no tolerance)")

    # Overall statistics
    print(f"\nTotal target dates: {len(dates)}")
    print(f"Date range: {dates.min().date()} to {dates.max().date()}")
    print(f"Time span: {(dates.max() - dates.min()).days} days ({(dates.max() - dates.min()).days/365.25:.1f} years)")

    # Check for future dates
    today = pd.Timestamp.now()
    future_dates = dates[dates > today]
    if len(future_dates) > 0:
        print(f"\n⚠ WARNING: {len(future_dates)} dates are in the future:")
        for fd in future_dates[:5]:
            print(f"  - {fd.date()}")
        if len(future_dates) > 5:
            print(f"  ... and {len(future_dates)-5} more")

    # Distribution by year
    print("\nDistribution by year:")
    year_counts = dates.year.value_counts().sort_index()
    for year, count in year_counts.items():
        print(f"  {year}: {count} dates")

    # Distribution by month
    print("\nDistribution by month:")
    month_counts = dates.month.value_counts().sort_index()
    month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                   'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    for month, count in month_counts.items():
        print(f"  {month_names[month-1]}: {count} dates")

    # Check Sentinel-2 availability
    s2a_start = pd.Timestamp('2017-03-28')
    pre_s2a = dates[dates < s2a_start]
    if len(pre_s2a) > 0:
        print(f"\n⚠ WARNING: {len(pre_s2a)} dates before Sentinel-2A:")
        for pd_date in pre_s2a:
            print(f"  - {pd_date.date()}")

    print("="*80 + "\n")

    return {
        'total': len(dates),
        'future': len(future_dates),
        'pre_s2a': len(pre_s2a),
        'processable': len(dates) - len(future_dates) - len(pre_s2a),
        'years': sorted(year_counts.index.tolist()),
        'year_counts': year_counts.to_dict()
    }

# ============================================================================
# OPTIMIZED SETTINGS
# ============================================================================

def get_processing_settings(output_year_dir=None):
    """
    Get optimized processing settings
    Balances speed and quality as requested
    """
    output_dir = output_year_dir if output_year_dir else OUTPUT_CONFIG['base_dir']

    settings = {
        # Geographic
        'limit': REGION_CONFIG['limit'],
        'region_name': REGION_CONFIG['region_name'],
        'st_lat': REGION_CONFIG['center_lat'],
        'st_lon': REGION_CONFIG['center_lon'],
        'polygon_limit': True,
        'st_crop': False,
        'st_box': 20,
        'subset_aot': False,
        'strict_subset': False,
        'region_name_add_box': False,
        'add_region_name_output': False,

        # Sensors and date
        'sensors': PROCESSING_CONFIG['sensors'],
        'surface_reflectance': False,
        'isodate_start': None,  # Will be set per scene
        'isodate_end': None,    # Will be set per scene
        'day_range': 1,
        'filter_tiles': None,

        # Resolution
        's2_target_res': 10,
        'output_scale': 10,

        # Atmospheric Correction - OPTIMIZED FOR SPEED + QUALITY
        'atmospheric_correction': True,
        'run_hybrid_dsf': True,  # Use DSF for quality

        # DSF optimization (balance speed and quality)
        'percentiles': [5, 25, 75],  # 3 percentiles (faster than 6)
        'pidx': 1,  # Use 25th percentile for turbid waters
        'nbands': 2,  # Use 2 bands (faster than 3)
        'sel_par': 'taua_cv',

        # Glint correction (critical for water)
        'glint_correction': True,
        'glint_min': 0.0,
        'glint_max': 0.05,
        'glint_wind': 2.0,

        # Ancillary data
        'ancillary_data': True,
        'uoz_default': 0.3,
        'uwv_default': 1.5,
        'pressure': 1013.25,
        'wind': None,

        # Atmospheric correction parameters
        'rhop_par': 'romix',

        # TACT parameters (required even if not using)
        'run_hybrid_tact': False,
        'reptran': 'reptran_fine',
        'source': 'era5',
        'emissivity': 'water',  # ← MISSING KEY - ADDED

        # Offline processing
        'run_offline_dsf': False,
        'run_offline_tact': False,

        # Output settings
        'output': output_dir,
        'convert_output': True,
        'store_output_locally': True,
        'store_output_google_drive': False,

        # What to store
        'store_rhot': True,
        'store_rhos': True,
        'store_geom': True,
        'store_sr': False,
        'store_st': False,
        'store_sp': False,

        # File management
        'l1r_delete_netcdf': False,
        'l2w_export_geotiff': False,
        'clear_output_zip_files': True,
        'override': False,
        'use_scene_name': False,

        # Processing optimization
        'tile_size': [512, 512],  # Balanced for speed and memory

        # Tasks
        'task_check_sleep': 10,
    }

    return settings

# ============================================================================
# SCENE FINDING WITH PROGRESS TRACKING
# ============================================================================

def find_all_scenes_for_dates(ac, gee, target_dates, show_progress=True):
    """
    Find scenes for EXACT target dates (no tolerance, no cloud filtering)
    These are known Sentinel-2 acquisition dates
    """
    print("="*80)
    print("SEARCHING FOR SENTINEL-2 SCENES")
    print("="*80)
    print(f"Target dates: {len(target_dates)}")
    print("Searching for EXACT dates (no tolerance, no cloud filtering)")
    print("="*80 + "\n")

    all_scenes = []
    dates_with_scenes = 0
    dates_without_scenes = 0

    for idx, target_date in enumerate(target_dates, 1):
        if show_progress:
            print(f"[{idx}/{len(target_dates)}] Searching: {target_date}...", end=' ')

        try:
            # Parse date
            dt = datetime.strptime(target_date, '%Y-%m-%d')

            # Check if date is in future
            if dt > datetime.now():
                print("⚠ Future date - skipping")
                continue

            # Check if before S2A
            if dt < datetime(2017, 3, 28):
                print("⚠ Before Sentinel-2A - skipping")
                continue

            # Search for EXACT date only (no tolerance)
            date_start = target_date
            date_end = (dt + timedelta(days=1)).strftime('%Y-%m-%d')

            # Search GEE
            images, imColl = gee.find_scenes(
                date_start,
                isodate_end=date_end,
                sensors=PROCESSING_CONFIG['sensors'],
                limit=REGION_CONFIG['limit'],
                surface_reflectance=False
            )

            if len(images) == 0:
                print("✗ No scenes found")
                dates_without_scenes += 1
                continue

            # Process each image found
            found_for_date = False
            for fkey, pid in images:
                try:
                    img = imColl.filter(ee.Filter.eq(fkey, pid)).first()
                    info = img.getInfo()
                    props = info['properties']

                    if 'PRODUCT_ID' not in props:
                        continue

                    # Extract date from PRODUCT_ID
                    product_id = props['PRODUCT_ID']

                    try:
                        date_str = product_id.split('_')[2][:8]
                        acq_date = f"{date_str[:4]}-{date_str[4:6]}-{date_str[6:8]}"
                    except:
                        acq_date = target_date

                    # Get other metadata safely
                    cloud_cover = float(props.get('CLOUDY_PIXEL_PERCENTAGE', -999))

                    scene_info = {
                        'target_date': target_date,
                        'acquisition_date': acq_date,
                        'days_from_target': 0,  # ← FIXED: Added this field
                        'product_id': pid,
                        'satellite': pid[0:3],
                        'tile': props.get('MGRS_TILE', ''),
                        'cloud_cover': cloud_cover,
                        'solar_zenith': float(props.get('MEAN_SOLAR_ZENITH_ANGLE', -999)),
                        'solar_azimuth': float(props.get('MEAN_SOLAR_AZIMUTH_ANGLE', -999)),
                        'processing_baseline': str(props.get('PROCESSING_BASELINE', '')),
                        'fkey': fkey,
                    }

                    all_scenes.append(scene_info)
                    found_for_date = True
                    print(f"✓ {pid[:30]}... ({cloud_cover:.1f}% clouds)")

                except Exception as e:
                    print(f"⚠ Error processing image: {str(e)}")
                    continue

            if found_for_date:
                dates_with_scenes += 1
            else:
                dates_without_scenes += 1

        except Exception as e:
            print(f"✗ Error: {str(e)}")
            dates_without_scenes += 1

    # Create DataFrame
    df = pd.DataFrame(all_scenes)

    print("\n" + "="*80)
    print("SCENE SEARCH SUMMARY")
    print("="*80)
    print(f"Target dates searched: {len(target_dates)}")
    print(f"Dates with scenes: {dates_with_scenes}")
    print(f"Dates without scenes: {dates_without_scenes}")
    print(f"Total scenes found: {len(df)}")

    if len(df) > 0:
        print(f"\nCloud cover range: {df['cloud_cover'].min():.1f}% - {df['cloud_cover'].max():.1f}%")
        print(f"Mean cloud cover: {df['cloud_cover'].mean():.1f}%")

        # Check if multiple images per date
        dates_with_multiple = df.groupby('target_date').size()
        multi_dates = dates_with_multiple[dates_with_multiple > 1]
        if len(multi_dates) > 0:
            print(f"\n⚠ {len(multi_dates)} dates have multiple images (different tiles):")
            for date, count in multi_dates.items():
                tiles = df[df['target_date']==date]['tile'].unique()
                print(f"  {date}: {count} images from tiles {', '.join(tiles)}")

    print("="*80 + "\n")

    # Save scene inventory
    if len(df) > 0:
        inventory_path = f"{OUTPUT_CONFIG['base_dir']}/scene_inventory.csv"
        df.to_csv(inventory_path, index=False)
        print(f"✓ Scene inventory saved: {inventory_path}\n")

    return df

# ============================================================================
# BATCH PROCESSING WITH CHECKPOINTING
# ============================================================================

def process_scenes_in_batches(ac, gee, scenes_df, settings, batch_size=20, start_idx=0):
    """
    Process scenes in batches with automatic checkpointing
    """
    print("="*80)
    print("BATCH PROCESSING WITH TURBIDITY CALCULATION")
    print("="*80)
    print(f"Total scenes: {len(scenes_df)}")
    print(f"Batch size: {batch_size}")
    print(f"Starting from: {start_idx}")
    print(f"Estimated time: {len(scenes_df) * 90 / 3600:.1f} hours")
    print("="*80 + "\n")

    # Initialize storage
    rsrd, lutd, luti = {}, {}, {}
    results = []

    # Get ImageCollection once
    print("Initializing GEE ImageCollection...")
    _, imColl = gee.find_scenes(
        scenes_df['acquisition_date'].min(),
        isodate_end=scenes_df['acquisition_date'].max(),
        sensors=settings['sensors'],
        limit=settings['limit'],
        surface_reflectance=False
    )
    print("✓ ImageCollection ready\n")

    # Process each scene
    for idx in range(start_idx, len(scenes_df)):
        scene = scenes_df.iloc[idx]

        # Update output directory for year-based organization
        if OUTPUT_CONFIG['organize_by_year']:
            year = scene['acquisition_date'][:4]
            settings['output'] = f"{OUTPUT_CONFIG['base_dir']}/{year}"

        print(f"\n{'='*80}")
        print(f"[{idx+1}/{len(scenes_df)}] PROCESSING: {scene['product_id']}")
        print(f"{'='*80}")
        print(f"Target date:     {scene['target_date']}")
        print(f"Acquisition:     {scene['acquisition_date']} (exact date)")  # ← CHANGED
        print(f"Tile:            {scene['tile']}")
        print(f"Cloud cover:     {scene['cloud_cover']:.1f}%")
        print(f"Solar zenith:    {scene['solar_zenith']:.2f}°")

        try:
            # Process with ACOLITE
            image = (scene['fkey'], scene['product_id'])
            t0 = time.time()

            ret = gee.agh(image, imColl, rsrd=rsrd, lutd=lutd, luti=luti, settings=settings)

            t1 = time.time()
            processing_time = t1 - t0

            if not ret or len(ret) == 0:
                raise ValueError("No output generated")

            nc_file = list(ret.values())[0]
            print(f"\n✓ Processing completed in {processing_time:.1f}s")
            print(f"✓ Output: {os.path.basename(nc_file)}")

            # Load and calculate turbidity
            print(f"  Calculating Nechad 2016 turbidity...")

            # Open, read, and close immediately
            import xarray as xr
            ds = xr.open_dataset(nc_file)
            rhos_665 = ds['rhos_665'].values
            aot_550 = float(ds.attrs.get('ac_aot_550', -999))
            ac_model = str(ds.attrs.get('ac_model', 'N/A'))
            ds.close()  # CRITICAL: Close immediately after reading

            # Calculate turbidity
            A_t, C_t = 610.94, 0.2324
            turbidity = A_t * (rhos_665 / (1 - rhos_665 / C_t))
            turbidity = np.where((rhos_665 < 0.001) | (rhos_665 > 0.3), np.nan, turbidity)

            # Calculate statistics
            turb_stats = {
                'mean': float(np.nanmean(turbidity)),
                'std': float(np.nanstd(turbidity)),
                'median': float(np.nanmedian(turbidity)),
                'min': float(np.nanmin(turbidity)),
                'max': float(np.nanmax(turbidity)),
                'valid_pct': float((~np.isnan(turbidity)).sum() / turbidity.size * 100)
            }

            # Write turbidity back to NetCDF using ACOLITE
            turb_attrs = {
                'algorithm': 'Nechad et al. 2016',
                'band': '665nm',
                'units': 'FNU',
                'A_t': A_t,
                'C_t': C_t
            }
            ac.output.nc_write(nc_file, 'tur_nechad2016', turbidity,
                              dataset_attributes=turb_attrs)

            print(f"  ✓ Turbidity: {turb_stats['mean']:.2f} FNU (mean)")
            print(f"    Range: {turb_stats['min']:.2f} - {turb_stats['max']:.2f} FNU")
            print(f"    Valid: {turb_stats['valid_pct']:.1f}%")

            # Store results
            result = scene.to_dict()
            result.update({
                'processing_time_s': processing_time,
                'output_file': nc_file,
                'turbidity_mean': turb_stats['mean'],
                'turbidity_std': turb_stats['std'],
                'turbidity_median': turb_stats['median'],
                'turbidity_min': turb_stats['min'],
                'turbidity_max': turb_stats['max'],
                'valid_pixels_pct': turb_stats['valid_pct'],
                'aot_550': aot_550,
                'ac_model': ac_model,
                'status': 'success',
                'error': ''
            })
            results.append(result)

        except Exception as e:
            print(f"\n✗ ERROR: {str(e)}")
            # ... rest of error handling ...
            print(f"\n✗ ERROR: {str(e)}")
            result = scene.to_dict()
            result.update({
                'status': 'failed',
                'error': str(e),
                'processing_time_s': 0,
                'output_file': '',
                'turbidity_mean': np.nan
            })
            results.append(result)

            import traceback
            traceback.print_exc()

        # Checkpoint: Save every batch_size scenes
        if (idx + 1) % batch_size == 0 or (idx + 1) == len(scenes_df):
            checkpoint_df = pd.DataFrame(results)
            checkpoint_path = f"{OUTPUT_CONFIG['base_dir']}/processing_checkpoint_{idx+1}.csv"
            checkpoint_df.to_csv(checkpoint_path, index=False)

            success_count = (checkpoint_df['status'] == 'success').sum()
            print(f"\n{'='*80}")
            print(f"💾 CHECKPOINT SAVED")
            print(f"{'='*80}")
            print(f"Processed: {idx+1}/{len(scenes_df)} scenes")
            print(f"Success: {success_count} | Failed: {len(checkpoint_df) - success_count}")
            print(f"Checkpoint: {checkpoint_path}")
            print(f"{'='*80}\n")

            # Memory cleanup
            import gc
            gc.collect()

    # Final save
    results_df = pd.DataFrame(results)
    final_path = f"{OUTPUT_CONFIG['base_dir']}/processing_results_final.csv"
    results_df.to_csv(final_path, index=False)

    print(f"\n{'='*80}")
    print("BATCH PROCESSING COMPLETE")
    print(f"{'='*80}")
    print(f"Total processed: {len(results_df)}")
    print(f"Successful: {(results_df['status']=='success').sum()}")
    print(f"Failed: {(results_df['status']=='failed').sum()}")
    print(f"Final results: {final_path}")
    print(f"{'='*80}\n")

    return results_df

# ============================================================================
# MAIN EXECUTION FUNCTION
# ============================================================================

def main():
    """
    Main execution function - Run everything
    """
    print("\n" + "="*80)
    print("ACOLITE-GEE PRODUCTION PROCESSING SYSTEM")
    print("Mississippi River Turbidity Monitoring")
    print("BelleChasse Region (2017-2025)")
    print("="*80 + "\n")

    # Step 1: Setup
    ac, gee = setup_environment()

    # Step 2: Analyze dates
    date_stats = analyze_target_dates(TARGET_DATES)

    # Step 3: Find scenes
    scenes_df = find_all_scenes_for_dates(ac, gee, TARGET_DATES)

    # Restrict/Define the tile for the image processing all tiles increases processing time
    # keep only one tile globally (e.g., 15RYP)
    preferred_tile = PROCESSING_CONFIG.get("preferred_tile", "15RYP")
    keep = scenes_df['tile'] == preferred_tile
    if keep.any():
        dropped = len(scenes_df) - keep.sum()
        scenes_df = scenes_df[keep].copy()
        print(f"Filtered to tile {preferred_tile}. Dropped {dropped} other-tile scene(s).")
    else:
        print(f"No scenes in tile {preferred_tile}; keeping all tiles for now.")

    # Optionally: still ensure one scene per date (if needed)
    scenes_df = (scenes_df
        .sort_values(['target_date','days_from_target','cloud_cover'])
        .groupby('target_date', as_index=False)
        .first()
    )

    if len(scenes_df) == 0:
        print("⚠ No scenes found. Exiting.")
        return None

    # Step 4: Get processing settings
    settings = get_processing_settings()

    # Step 5: Process scenes
    results_df = process_scenes_in_batches(
        ac, gee, scenes_df, settings,
        batch_size=PROCESSING_CONFIG['batch_size'],
        start_idx=0
    )

    # Step 6: Summary
    print("\n" + "="*80)
    print("FINAL SUMMARY")
    print("="*80)
    print(f"Target dates: {len(TARGET_DATES)}")
    print(f"Scenes found: {len(scenes_df)}")
    print(f"Successfully processed: {(results_df['status']=='success').sum()}")
    print(f"Failed: {(results_df['status']=='failed').sum()}")

    if (results_df['status']=='success').sum() > 0:
        success_df = results_df[results_df['status']=='success']
        print(f"\nTurbidity statistics:")
        print(f"  Mean: {success_df['turbidity_mean'].mean():.2f} ± {success_df['turbidity_mean'].std():.2f} FNU")
        print(f"  Range: {success_df['turbidity_min'].min():.2f} - {success_df['turbidity_max'].max():.2f} FNU")
        print(f"\nProcessing time:")
        print(f"  Total: {success_df['processing_time_s'].sum()/3600:.1f} hours")
        print(f"  Average: {success_df['processing_time_s'].mean():.1f}s per scene")

    print(f"\nOutput directory: {OUTPUT_CONFIG['base_dir']}")
    print("="*80 + "\n")

    return results_df

# ============================================================================
# RUN THE SYSTEM
# ============================================================================

if __name__ == "__main__":
    results = main()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761021537.853181   12881 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761021537.873169   12881 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761021537.938698   12881 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761021537.938793   12881 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761021537.938804   12881 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761021537.938812   12881 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Successfully saved project id
# ✓ Imported ACOLITE from /content/drive/MyDrive/ACOLITE
#
# ================================================================================
# ACOLITE-GEE PRODUCTION PROCESSING SYSTEM
# Mississippi River Turbidity Monitoring
# BelleChasse Region (2017-2025)
# ================================================================================
#
# ================================================================================
# ACOLITE-GEE PRODUCTION SYSTEM - ENVIRONMENT SETUP
# ================================================================================
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✓ Google Drive mounted
# ✓ ACOLITE loaded from: /content/drive/MyDrive/ACOLITE
#
# Initializing Google Earth Engine...
# ✓ Earth Engine initialized with project 'eaadeniyi'
# ✓ Created output directories for years: ['2022']
# ================================================================================
# ✓ ENVIRONMENT SETUP COMPLETE
#
# ================================================================================
# TARGET DATES ANALYSIS
# ================================================================================
# These are EXACT Sentinel-2 acquisition dates (no tolerance)
#
# Total target dates: 1
# Date range: 2022-03-31 to 2022-03-31
# Time span: 0 days (0.0 years)
#
# Distribution by year:
#   2022: 1 dates
#
# Distribution by month:
#   Mar: 1 dates
# ================================================================================
#
# ================================================================================
# SEARCHING FOR SENTINEL-2 SCENES
# ================================================================================
# Target dates: 1
# Searching for EXACT dates (no tolerance, no cloud filtering)
# ================================================================================
#
# [1/1] Searching: 2022-03-31... Date range 2022-03-31 2022-04-02
# Checking collections COPERNICUS/S2_HARMONIZED
# ✓ S2B_MSIL1C_20220331T163839_N04... (41.1% clouds)
# ✓ S2B_MSIL1C_20220331T163839_N04... (1.1% clouds)
# ✓ S2B_MSIL1C_20220331T163839_N04... (45.0% clouds)
# ✓ S2B_MSIL1C_20220331T163839_N04... (3.6% clouds)
#
# ================================================================================
# SCENE SEARCH SUMMARY
# ================================================================================
# Target dates searched: 1
# Dates with scenes: 1
# Dates without scenes: 0
# Total scenes found: 4
#
# Cloud cover range: 1.1% - 45.0%
# Mean cloud cover: 22.7%
#
# ⚠ 1 dates have multiple images (different tiles):
#   2022-03-31: 4 images from tiles 15RYN, 15RYP, 16RBT, 16RBU
# ================================================================================
#
# ✓ Scene inventory saved: /content/drive/MyDrive/ACOLITE_Output_Production/scene_inventory.csv
#
# ================================================================================
# BATCH PROCESSING WITH TURBIDITY CALCULATION
# ================================================================================
# Total scenes: 4
# Batch size: 20
# Starting from: 0
# Estimated time: 0.1 hours
# ================================================================================
#
# Initializing GEE ImageCollection...
# Date range 2022-03-31 2022-04-01
# Checking collections COPERNICUS/S2_HARMONIZED
# ✓ ImageCollection ready
#
#
# ================================================================================
# [1/4] PROCESSING: S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802
# ================================================================================
# Target date:     2022-03-31
# Acquisition:     2022-03-31 (exact date)
# Tile:            15RYN
# Cloud cover:     41.1%
# Solar zenith:    30.00°
# Scene dimensions [10980, 10980]
# Scene origin (0, 0)
# EPSG:32615
# [10, 0, 699960, 0, -10, 3300000]
# Scene centre: -90.37600E 29.30919N
# Loading RSRs: S2B_MSI
# Getting ancillary for scene centre location.
# Could not determine earthdata credentials. Please add them to your .netrc file or ACOLITE credentials file.
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20220331T160000.MET.nc
# Could not determine earthdata credentials. Please add them to your .netrc file or ACOLITE credentials file.
# EARTHDATA user name and password required for download of https://oceandata.sci.gsfc.nasa.gov/ob/getfile/GMAO_MERRA2.20220331T170000.MET.nc
# 0.3 1.5 None 1013.25
# Loading atmosphere LUTs: S2B_MSI
# Loading interface LUTs: S2B_MSI
# rhot B1
# rhot B2
# rhot B3
# rhot B4
# rhot B5
# rhot B6
# rhot B7
# rhot B8
# rhot B8A
# rhot B9
# rhot B10
# rhot B11
# rhot B12
# ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B10', 'B11', 'B12']
# Getting geometry and gas transmittance
# Extracting rhot percentiles
# Fitting aerosol models
# S2B_MSI 1 ACOLITE-LUT-202110-MOD1
# S2B_MSI 2 ACOLITE-LUT-202110-MOD1
# S2B_MSI 3 ACOLITE-LUT-202110-MOD1
# S2B_MSI 4 ACOLITE-LUT-202110-MOD1
# S2B_MSI 5 ACOLITE-LUT-202110-MOD1
# S2B_MSI 6 ACOLITE-LUT-202110-MOD1
# S2B_MSI 7 ACOLITE-LUT-202110-MOD1
# S2B_MSI 8 ACOLITE-LUT-202110-MOD1
# S2B_MSI 8A ACOLITE-LUT-202110-MOD1
# S2B_MSI 11 ACOLITE-LUT-202110-MOD1
# S2B_MSI 12 ACOLITE-LUT-202110-MOD1
# S2B_MSI 1 ACOLITE-LUT-202110-MOD2
# S2B_MSI 2 ACOLITE-LUT-202110-MOD2
# S2B_MSI 3 ACOLITE-LUT-202110-MOD2
# S2B_MSI 4 ACOLITE-LUT-202110-MOD2
# S2B_MSI 5 ACOLITE-LUT-202110-MOD2
# S2B_MSI 6 ACOLITE-LUT-202110-MOD2
# S2B_MSI 7 ACOLITE-LUT-202110-MOD2
# S2B_MSI 8 ACOLITE-LUT-202110-MOD2
# S2B_MSI 8A ACOLITE-LUT-202110-MOD2
# S2B_MSI 11 ACOLITE-LUT-202110-MOD2
# S2B_MSI 12 ACOLITE-LUT-202110-MOD2
# Getting final atmosphere parameters
# ACOLITE-LUT-202110-MOD2 0.6244055808056876 0.058263547390068095
# Performing DSF atmospheric correction
# Performing glint correction using bands 11 12
# (np.float64(7248.0), np.float64(-1992.0))
# (3882, 3390)
# tile [np.float64(7248.0), np.float64(7760.0), np.float64(-1992.0), np.float64(-1480.0), 't000']
# tile [np.float64(7248.0), np.float64(7760.0), np.float64(-1480.0), np.float64(-968.0), 't001']
# tile [np.float64(7248.0), np.float64(7760.0), np.float64(-968.0), np.float64(-456.0), 't002']
# tile [np.float64(7248.0), np.float64(7760.0), np.float64(-456.0), np.float64(56.0), 't003']
# tile [np.float64(7248.0), np.float64(7760.0), np.float64(56.0), np.float64(568.0), 't004']
# tile [np.float64(7248.0), np.float64(7760.0), np.float64(568.0), np.float64(1080.0), 't005']
# tile [np.float64(7248.0), np.float64(7760.0), np.float64(1080.0), np.float64(1398.0), 't006']
# tile [np.float64(7760.0), np.float64(8272.0), np.float64(-1992.0), np.float64(-1480.0), 't007']
# tile [np.float64(7760.0), np.float64(8272.0), np.float64(-1480.0), np.float64(-968.0), 't008']
# tile [np.float64(7760.0), np.float64(8272.0), np.float64(-968.0), np.float64(-456.0), 't009']
# tile [np.float64(7760.0), np.float64(8272.0), np.float64(-456.0), np.float64(56.0), 't010']
# tile [np.float64(7760.0), np.float64(8272.0), np.float64(56.0), np.float64(568.0), 't011']
# tile [np.float64(7760.0), np.float64(8272.0), np.float64(568.0), np.float64(1080.0), 't012']
# tile [np.float64(7760.0), np.float64(8272.0), np.float64(1080.0), np.float64(1398.0), 't013']
# tile [np.float64(8272.0), np.float64(8784.0), np.float64(-1992.0), np.float64(-1480.0), 't014']
# tile [np.float64(8272.0), np.float64(8784.0), np.float64(-1480.0), np.float64(-968.0), 't015']
# tile [np.float64(8272.0), np.float64(8784.0), np.float64(-968.0), np.float64(-456.0), 't016']
# tile [np.float64(8272.0), np.float64(8784.0), np.float64(-456.0), np.float64(56.0), 't017']
# tile [np.float64(8272.0), np.float64(8784.0), np.float64(56.0), np.float64(568.0), 't018']
# tile [np.float64(8272.0), np.float64(8784.0), np.float64(568.0), np.float64(1080.0), 't019']
# tile [np.float64(8272.0), np.float64(8784.0), np.float64(1080.0), np.float64(1398.0), 't020']
# tile [np.float64(8784.0), np.float64(9296.0), np.float64(-1992.0), np.float64(-1480.0), 't021']
# tile [np.float64(8784.0), np.float64(9296.0), np.float64(-1480.0), np.float64(-968.0), 't022']
# tile [np.float64(8784.0), np.float64(9296.0), np.float64(-968.0), np.float64(-456.0), 't023']
# tile [np.float64(8784.0), np.float64(9296.0), np.float64(-456.0), np.float64(56.0), 't024']
# tile [np.float64(8784.0), np.float64(9296.0), np.float64(56.0), np.float64(568.0), 't025']
# tile [np.float64(8784.0), np.float64(9296.0), np.float64(568.0), np.float64(1080.0), 't026']
# tile [np.float64(8784.0), np.float64(9296.0), np.float64(1080.0), np.float64(1398.0), 't027']
# tile [np.float64(9296.0), np.float64(9808.0), np.float64(-1992.0), np.float64(-1480.0), 't028']
# tile [np.float64(9296.0), np.float64(9808.0), np.float64(-1480.0), np.float64(-968.0), 't029']
# tile [np.float64(9296.0), np.float64(9808.0), np.float64(-968.0), np.float64(-456.0), 't030']
# tile [np.float64(9296.0), np.float64(9808.0), np.float64(-456.0), np.float64(56.0), 't031']
# tile [np.float64(9296.0), np.float64(9808.0), np.float64(56.0), np.float64(568.0), 't032']
# tile [np.float64(9296.0), np.float64(9808.0), np.float64(568.0), np.float64(1080.0), 't033']
# tile [np.float64(9296.0), np.float64(9808.0), np.float64(1080.0), np.float64(1398.0), 't034']
# tile [np.float64(9808.0), np.float64(10320.0), np.float64(-1992.0), np.float64(-1480.0), 't035']
# tile [np.float64(9808.0), np.float64(10320.0), np.float64(-1480.0), np.float64(-968.0), 't036']
# tile [np.float64(9808.0), np.float64(10320.0), np.float64(-968.0), np.float64(-456.0), 't037']
# tile [np.float64(9808.0), np.float64(10320.0), np.float64(-456.0), np.float64(56.0), 't038']
# tile [np.float64(9808.0), np.float64(10320.0), np.float64(56.0), np.float64(568.0), 't039']
# tile [np.float64(9808.0), np.float64(10320.0), np.float64(568.0), np.float64(1080.0), 't040']
# tile [np.float64(9808.0), np.float64(10320.0), np.float64(1080.0), np.float64(1398.0), 't041']
# tile [np.float64(10320.0), np.float64(10832.0), np.float64(-1992.0), np.float64(-1480.0), 't042']
# tile [np.float64(10320.0), np.float64(10832.0), np.float64(-1480.0), np.float64(-968.0), 't043']
# tile [np.float64(10320.0), np.float64(10832.0), np.float64(-968.0), np.float64(-456.0), 't044']
# tile [np.float64(10320.0), np.float64(10832.0), np.float64(-456.0), np.float64(56.0), 't045']
# tile [np.float64(10320.0), np.float64(10832.0), np.float64(56.0), np.float64(568.0), 't046']
# tile [np.float64(10320.0), np.float64(10832.0), np.float64(568.0), np.float64(1080.0), 't047']
# tile [np.float64(10320.0), np.float64(10832.0), np.float64(1080.0), np.float64(1398.0), 't048']
# tile [np.float64(10832.0), np.float64(11130.0), np.float64(-1992.0), np.float64(-1480.0), 't049']
# tile [np.float64(10832.0), np.float64(11130.0), np.float64(-1480.0), np.float64(-968.0), 't050']
# tile [np.float64(10832.0), np.float64(11130.0), np.float64(-968.0), np.float64(-456.0), 't051']
# tile [np.float64(10832.0), np.float64(11130.0), np.float64(-456.0), np.float64(56.0), 't052']
# tile [np.float64(10832.0), np.float64(11130.0), np.float64(56.0), np.float64(568.0), 't053']
# tile [np.float64(10832.0), np.float64(11130.0), np.float64(568.0), np.float64(1080.0), 't054']
# tile [np.float64(10832.0), np.float64(11130.0), np.float64(1080.0), np.float64(1398.0), 't055']
# [10, 0, 699960, 0, -10, 3300000]
# Running download with 56 tiles
# [np.float64(7248.0), np.float64(7760.0), np.float64(-1992.0), np.float64(-1480.0), 't000']
# (np.float64(512.0), np.float64(512.0))
# 772440.0 3319920.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(772440.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3319920.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(7248.0), np.float64(7760.0), np.float64(-1480.0), np.float64(-968.0), 't001']
# (np.float64(512.0), np.float64(512.0))
# 772440.0 3314800.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(772440.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3314800.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(7248.0), np.float64(7760.0), np.float64(-968.0), np.float64(-456.0), 't002']
# (np.float64(512.0), np.float64(512.0))
# 772440.0 3309680.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(772440.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3309680.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(7248.0), np.float64(7760.0), np.float64(-456.0), np.float64(56.0), 't003']
# (np.float64(512.0), np.float64(512.0))
# 772440.0 3304560.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(772440.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3304560.0)}, 'crsCode': 'EPSG:32615'}
# rhot 536253
# rhos 1170964
# [np.float64(7248.0), np.float64(7760.0), np.float64(56.0), np.float64(568.0), 't004']
# (np.float64(512.0), np.float64(512.0))
# 772440.0 3299440.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(772440.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3299440.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4396359
# rhos 11165984
# [np.float64(7248.0), np.float64(7760.0), np.float64(568.0), np.float64(1080.0), 't005']
# (np.float64(512.0), np.float64(512.0))
# 772440.0 3294320.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(772440.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3294320.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4527819
# rhos 10897822
# [np.float64(7248.0), np.float64(7760.0), np.float64(1080.0), np.float64(1398.0), 't006']
# (np.float64(512.0), np.float64(318.0))
# 772440.0 3289200.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(318.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(772440.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3289200.0)}, 'crsCode': 'EPSG:32615'}
# rhot 2824913
# rhos 7611554
# [np.float64(7760.0), np.float64(8272.0), np.float64(-1992.0), np.float64(-1480.0), 't007']
# (np.float64(512.0), np.float64(512.0))
# 777560.0 3319920.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(777560.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3319920.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(7760.0), np.float64(8272.0), np.float64(-1480.0), np.float64(-968.0), 't008']
# (np.float64(512.0), np.float64(512.0))
# 777560.0 3314800.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(777560.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3314800.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(7760.0), np.float64(8272.0), np.float64(-968.0), np.float64(-456.0), 't009']
# (np.float64(512.0), np.float64(512.0))
# 777560.0 3309680.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(777560.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3309680.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(7760.0), np.float64(8272.0), np.float64(-456.0), np.float64(56.0), 't010']
# (np.float64(512.0), np.float64(512.0))
# 777560.0 3304560.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(777560.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3304560.0)}, 'crsCode': 'EPSG:32615'}
# rhot 550770
# rhos 916750
# [np.float64(7760.0), np.float64(8272.0), np.float64(56.0), np.float64(568.0), 't011']
# (np.float64(512.0), np.float64(512.0))
# 777560.0 3299440.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(777560.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3299440.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4747572
# rhos 8864857
# [np.float64(7760.0), np.float64(8272.0), np.float64(568.0), np.float64(1080.0), 't012']
# (np.float64(512.0), np.float64(512.0))
# 777560.0 3294320.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(777560.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3294320.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4707705
# rhos 10812673
# [np.float64(7760.0), np.float64(8272.0), np.float64(1080.0), np.float64(1398.0), 't013']
# (np.float64(512.0), np.float64(318.0))
# 777560.0 3289200.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(318.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(777560.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3289200.0)}, 'crsCode': 'EPSG:32615'}
# rhot 2882327
# rhos 7129738
# [np.float64(8272.0), np.float64(8784.0), np.float64(-1992.0), np.float64(-1480.0), 't014']
# (np.float64(512.0), np.float64(512.0))
# 782680.0 3319920.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(782680.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3319920.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(8272.0), np.float64(8784.0), np.float64(-1480.0), np.float64(-968.0), 't015']
# (np.float64(512.0), np.float64(512.0))
# 782680.0 3314800.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(782680.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3314800.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(8272.0), np.float64(8784.0), np.float64(-968.0), np.float64(-456.0), 't016']
# (np.float64(512.0), np.float64(512.0))
# 782680.0 3309680.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(782680.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3309680.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(8272.0), np.float64(8784.0), np.float64(-456.0), np.float64(56.0), 't017']
# (np.float64(512.0), np.float64(512.0))
# 782680.0 3304560.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(782680.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3304560.0)}, 'crsCode': 'EPSG:32615'}
# rhot 554954
# rhos 1040058
# [np.float64(8272.0), np.float64(8784.0), np.float64(56.0), np.float64(568.0), 't018']
# (np.float64(512.0), np.float64(512.0))
# 782680.0 3299440.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(782680.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3299440.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4732312
# rhos 10177757
# [np.float64(8272.0), np.float64(8784.0), np.float64(568.0), np.float64(1080.0), 't019']
# (np.float64(512.0), np.float64(512.0))
# 782680.0 3294320.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(782680.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3294320.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4657093
# rhos 11519251
# [np.float64(8272.0), np.float64(8784.0), np.float64(1080.0), np.float64(1398.0), 't020']
# (np.float64(512.0), np.float64(318.0))
# 782680.0 3289200.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(318.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(782680.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3289200.0)}, 'crsCode': 'EPSG:32615'}
# rhot 2869385
# rhos 7210304
# [np.float64(8784.0), np.float64(9296.0), np.float64(-1992.0), np.float64(-1480.0), 't021']
# (np.float64(512.0), np.float64(512.0))
# 787800.0 3319920.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(787800.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3319920.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(8784.0), np.float64(9296.0), np.float64(-1480.0), np.float64(-968.0), 't022']
# (np.float64(512.0), np.float64(512.0))
# 787800.0 3314800.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(787800.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3314800.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(8784.0), np.float64(9296.0), np.float64(-968.0), np.float64(-456.0), 't023']
# (np.float64(512.0), np.float64(512.0))
# 787800.0 3309680.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(787800.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3309680.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(8784.0), np.float64(9296.0), np.float64(-456.0), np.float64(56.0), 't024']
# (np.float64(512.0), np.float64(512.0))
# 787800.0 3304560.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(787800.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3304560.0)}, 'crsCode': 'EPSG:32615'}
# rhot 557463
# rhos 1154520
# [np.float64(8784.0), np.float64(9296.0), np.float64(56.0), np.float64(568.0), 't025']
# (np.float64(512.0), np.float64(512.0))
# 787800.0 3299440.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(787800.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3299440.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4773236
# rhos 10500667
# [np.float64(8784.0), np.float64(9296.0), np.float64(568.0), np.float64(1080.0), 't026']
# (np.float64(512.0), np.float64(512.0))
# 787800.0 3294320.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(787800.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3294320.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4735094
# rhos 11060614
# [np.float64(8784.0), np.float64(9296.0), np.float64(1080.0), np.float64(1398.0), 't027']
# (np.float64(512.0), np.float64(318.0))
# 787800.0 3289200.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(318.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(787800.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3289200.0)}, 'crsCode': 'EPSG:32615'}
# rhot 2982299
# rhos 6476686
# [np.float64(9296.0), np.float64(9808.0), np.float64(-1992.0), np.float64(-1480.0), 't028']
# (np.float64(512.0), np.float64(512.0))
# 792920.0 3319920.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(792920.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3319920.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(9296.0), np.float64(9808.0), np.float64(-1480.0), np.float64(-968.0), 't029']
# (np.float64(512.0), np.float64(512.0))
# 792920.0 3314800.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(792920.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3314800.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(9296.0), np.float64(9808.0), np.float64(-968.0), np.float64(-456.0), 't030']
# (np.float64(512.0), np.float64(512.0))
# 792920.0 3309680.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(792920.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3309680.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(9296.0), np.float64(9808.0), np.float64(-456.0), np.float64(56.0), 't031']
# (np.float64(512.0), np.float64(512.0))
# 792920.0 3304560.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(792920.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3304560.0)}, 'crsCode': 'EPSG:32615'}
# rhot 546931
# rhos 1271673
# [np.float64(9296.0), np.float64(9808.0), np.float64(56.0), np.float64(568.0), 't032']
# (np.float64(512.0), np.float64(512.0))
# 792920.0 3299440.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(792920.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3299440.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4723562
# rhos 11037675
# [np.float64(9296.0), np.float64(9808.0), np.float64(568.0), np.float64(1080.0), 't033']
# (np.float64(512.0), np.float64(512.0))
# 792920.0 3294320.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(792920.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3294320.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4714179
# rhos 11247931
# [np.float64(9296.0), np.float64(9808.0), np.float64(1080.0), np.float64(1398.0), 't034']
# (np.float64(512.0), np.float64(318.0))
# 792920.0 3289200.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(318.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(792920.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3289200.0)}, 'crsCode': 'EPSG:32615'}
# rhot 2956496
# rhos 6773970
# [np.float64(9808.0), np.float64(10320.0), np.float64(-1992.0), np.float64(-1480.0), 't035']
# (np.float64(512.0), np.float64(512.0))
# 798040.0 3319920.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(798040.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3319920.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(9808.0), np.float64(10320.0), np.float64(-1480.0), np.float64(-968.0), 't036']
# (np.float64(512.0), np.float64(512.0))
# 798040.0 3314800.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(798040.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3314800.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(9808.0), np.float64(10320.0), np.float64(-968.0), np.float64(-456.0), 't037']
# (np.float64(512.0), np.float64(512.0))
# 798040.0 3309680.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(798040.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3309680.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(9808.0), np.float64(10320.0), np.float64(-456.0), np.float64(56.0), 't038']
# (np.float64(512.0), np.float64(512.0))
# 798040.0 3304560.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(798040.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3304560.0)}, 'crsCode': 'EPSG:32615'}
# rhot 513624
# rhos 1405198
# [np.float64(9808.0), np.float64(10320.0), np.float64(56.0), np.float64(568.0), 't039']
# (np.float64(512.0), np.float64(512.0))
# 798040.0 3299440.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(798040.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3299440.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4652372
# rhos 12239546
# [np.float64(9808.0), np.float64(10320.0), np.float64(568.0), np.float64(1080.0), 't040']
# (np.float64(512.0), np.float64(512.0))
# 798040.0 3294320.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(798040.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3294320.0)}, 'crsCode': 'EPSG:32615'}
# rhot 4658700
# rhos 11738356
# [np.float64(9808.0), np.float64(10320.0), np.float64(1080.0), np.float64(1398.0), 't041']
# (np.float64(512.0), np.float64(318.0))
# 798040.0 3289200.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(318.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(798040.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3289200.0)}, 'crsCode': 'EPSG:32615'}
# rhot 2607172
# rhos 6446049
# [np.float64(10320.0), np.float64(10832.0), np.float64(-1992.0), np.float64(-1480.0), 't042']
# (np.float64(512.0), np.float64(512.0))
# 803160.0 3319920.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(803160.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3319920.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(10320.0), np.float64(10832.0), np.float64(-1480.0), np.float64(-968.0), 't043']
# (np.float64(512.0), np.float64(512.0))
# 803160.0 3314800.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(803160.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3314800.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(10320.0), np.float64(10832.0), np.float64(-968.0), np.float64(-456.0), 't044']
# (np.float64(512.0), np.float64(512.0))
# 803160.0 3309680.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(803160.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3309680.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(10320.0), np.float64(10832.0), np.float64(-456.0), np.float64(56.0), 't045']
# (np.float64(512.0), np.float64(512.0))
# 803160.0 3304560.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(803160.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3304560.0)}, 'crsCode': 'EPSG:32615'}
# rhot 223565
# rhos 439614
# [np.float64(10320.0), np.float64(10832.0), np.float64(56.0), np.float64(568.0), 't046']
# (np.float64(512.0), np.float64(512.0))
# 803160.0 3299440.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(803160.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3299440.0)}, 'crsCode': 'EPSG:32615'}
# rhot 1415325
# rhos 3210267
# [np.float64(10320.0), np.float64(10832.0), np.float64(568.0), np.float64(1080.0), 't047']
# (np.float64(512.0), np.float64(512.0))
# 803160.0 3294320.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(803160.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3294320.0)}, 'crsCode': 'EPSG:32615'}
# rhot 399719
# rhos 652191
# [np.float64(10320.0), np.float64(10832.0), np.float64(1080.0), np.float64(1398.0), 't048']
# (np.float64(512.0), np.float64(318.0))
# 803160.0 3289200.0
# {'dimensions': {'width': np.float64(512.0), 'height': np.float64(318.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(803160.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3289200.0)}, 'crsCode': 'EPSG:32615'}
# rhot 27044
# rhos 27044
# [np.float64(10832.0), np.float64(11130.0), np.float64(-1992.0), np.float64(-1480.0), 't049']
# (np.float64(298.0), np.float64(512.0))
# 808280.0 3319920.0
# {'dimensions': {'width': np.float64(298.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(808280.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3319920.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(10832.0), np.float64(11130.0), np.float64(-1480.0), np.float64(-968.0), 't050']
# (np.float64(298.0), np.float64(512.0))
# 808280.0 3314800.0
# {'dimensions': {'width': np.float64(298.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(808280.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3314800.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(10832.0), np.float64(11130.0), np.float64(-968.0), np.float64(-456.0), 't051']
# (np.float64(298.0), np.float64(512.0))
# 808280.0 3309680.0
# {'dimensions': {'width': np.float64(298.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(808280.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3309680.0)}, 'crsCode': 'EPSG:32615'}
# rhot 3836
# rhos 3836
# [np.float64(10832.0), np.float64(11130.0), np.float64(-456.0), np.float64(56.0), 't052']
# (np.float64(298.0), np.float64(512.0))
# 808280.0 3304560.0
# {'dimensions': {'width': np.float64(298.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(808280.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3304560.0)}, 'crsCode': 'EPSG:32615'}
# rhot 27044
# rhos 27044
# [np.float64(10832.0), np.float64(11130.0), np.float64(56.0), np.float64(568.0), 't053']
# (np.float64(298.0), np.float64(512.0))
# 808280.0 3299440.0
# {'dimensions': {'width': np.float64(298.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(808280.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3299440.0)}, 'crsCode': 'EPSG:32615'}
# rhot 27044
# rhos 27044
# [np.float64(10832.0), np.float64(11130.0), np.float64(568.0), np.float64(1080.0), 't054']
# (np.float64(298.0), np.float64(512.0))
# 808280.0 3294320.0
# {'dimensions': {'width': np.float64(298.0), 'height': np.float64(512.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(808280.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3294320.0)}, 'crsCode': 'EPSG:32615'}
# rhot 27044
# rhos 27044
# [np.float64(10832.0), np.float64(11130.0), np.float64(1080.0), np.float64(1398.0), 't055']
# (np.float64(298.0), np.float64(318.0))
# 808280.0 3289200.0
# {'dimensions': {'width': np.float64(298.0), 'height': np.float64(318.0)}, 'affineTransform': {'scaleX': 10, 'shearX': 0, 'translateX': np.float64(808280.0), 'shearY': 0, 'scaleY': -10, 'translateY': np.float64(3289200.0)}, 'crsCode': 'EPSG:32615'}
# rhot 27044
# rhos 27044
# /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSI_2022_03_31_16_49_45_15RYN_L2R_GEE_HYBRID_BelleChasse-Region.nc
# Failed to write attribute: system:footprint
# Wrote lon
# Wrote lat
# Wrote rhot_442
# Wrote rhos_442
# Wrote rhot_492
# Wrote rhos_492
# Wrote rhot_559
# Wrote rhos_559
# Wrote rhot_665
# Wrote rhos_665
# Wrote rhot_704
# Wrote rhos_704
# Wrote rhot_739
# Wrote rhos_739
# Wrote rhot_780
# Wrote rhos_780
# Wrote rhot_833
# Wrote rhos_833
# Wrote rhot_864
# Wrote rhos_864
# Wrote rhot_943
# Wrote rhot_1377
# Wrote rhot_1610
# Wrote rhos_1610
# Wrote rhot_2186
# Wrote rhos_2186
# Wrote /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSI_2022_03_31_16_49_45_15RYN_L2R_GEE_HYBRID_BelleChasse-Region.nc
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t000.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t001.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t002.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t003.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t004.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t005.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t006.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t007.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t008.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t009.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t010.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t011.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t012.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t013.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t014.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t015.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t016.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t017.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t018.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t019.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t020.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t021.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t022.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t023.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t024.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t025.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t026.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t027.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t028.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t029.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t030.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t031.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t032.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t033.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t034.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t035.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t036.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t037.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t038.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t039.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t040.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t041.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t042.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t043.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t044.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t045.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t046.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t047.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t048.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t049.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t050.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t051.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t052.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t053.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t054.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhot_BelleChasse-Region_t055.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t000.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t001.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t002.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t003.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t004.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t005.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t006.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t007.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t008.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t009.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t010.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t011.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t012.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t013.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t014.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t015.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t016.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T15RYN_20220331T203802_rhos_BelleChasse-Region_t017.tif
# ...
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t021.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t022.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t023.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t024.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t025.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t026.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t027.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t028.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t029.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t030.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t031.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t032.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t033.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t034.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t035.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t036.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t037.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t038.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t039.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t040.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t041.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t042.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t043.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t044.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t045.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t046.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t047.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t048.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t049.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t050.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t051.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t052.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t053.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t054.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhot_BelleChasse-Region_t055.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t000.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t001.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t002.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t003.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t004.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t005.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t006.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t007.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t008.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t009.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t010.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t011.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t012.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t013.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t014.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t015.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t016.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t017.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t018.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t019.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t020.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t021.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t022.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t023.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t024.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t025.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t026.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t027.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t028.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t029.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t030.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t031.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t032.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t033.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t034.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t035.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t036.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t037.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t038.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t039.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t040.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t041.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t042.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t043.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t044.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t045.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t046.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t047.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t048.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t049.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t050.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t051.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t052.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t053.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t054.tif
# Removing /content/drive/MyDrive/ACOLITE_Output_Production/2022/S2B_MSIL1C_20220331T163839_N0400_R126_T16RBU_20220331T203802_rhos_BelleChasse-Region_t055.tif
#
# ✓ Processing completed in 274.6s
# ✓ Output: S2B_MSI_2022_03_31_16_49_45_16RBU_L2R_GEE_HYBRID_BelleChasse-Region.nc
#   Calculating Nechad 2016 turbidity...
#   ✓ Turbidity: 33.26 FNU (mean)
#     Range: -1609648.88 - 312055.97 FNU
#     Valid: 57.9%
#
# ================================================================================
# 💾 CHECKPOINT SAVED
# ================================================================================
# Processed: 4/4 scenes
# Success: 4 | Failed: 0
# Checkpoint: /content/drive/MyDrive/ACOLITE_Output_Production/processing_checkpoint_4.csv
# ================================================================================
#
#
# ================================================================================
# BATCH PROCESSING COMPLETE
# ================================================================================
# Total processed: 4
# Successful: 4
# Failed: 0
# Final results: /content/drive/MyDrive/ACOLITE_Output_Production/processing_results_final.csv
# ================================================================================
#
#
# ================================================================================
# FINAL SUMMARY
# ================================================================================
# Target dates: 1
# Scenes found: 4
# Successfully processed: 4
# Failed: 0
#
# Turbidity statistics:
#   Mean: 36.79 ± 11.02 FNU
#   Range: -1609648.88 - 1808567.50 FNU
#
# Processing time:
#   Total: 0.3 hours
#   Average: 284.3s per scene
#
# Output directory: /content/drive/MyDrive/ACOLITE_Output_Production
# ================================================================================
